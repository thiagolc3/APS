# %% [markdown]
# <a href="https://colab.research.google.com/github/thiagolc3/APS/blob/master/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ea32f0c6-51ef-4022-943d-42b44016acaa" name="files[]" multiple disabled />
#      <output id="result-ea32f0c6-51ef-4022-943d-42b44016acaa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving grafana_data_export (56).csv to grafana_data_export (56).csv

# %%
# !pip install scipy==1.2 --upgrade

# %%
import pandas as pd
df = pd.read_csv("grafana_data_export (56).csv", error_bad_lines=False, sep=';', usecols=[0,1,2,3,4,5,8,10], decimal='.', parse_dates=True)

print(df.head())
# Out:
#                   Time  ...  sensorsLogger.CO2STD
# 0  2019-04-13T00:59:00  ...               422.325
# 1  2019-04-13T01:00:00  ...               422.317
# 2  2019-04-13T01:01:00  ...               422.317
# 3  2019-04-13T01:02:00  ...               422.342
# 4  2019-04-13T01:03:00  ...               422.375
#
# [5 rows x 8 columns]

# %%
import matplotlib
import matplotlib.pyplot as plt
import statsmodels.api as sm

decomposition = sm.tsa.seasonal_decompose(df['sensorsLogger.CO2STD'], model='additive', freq=1440)
a = decomposition.resid
decomposition = sm.tsa.seasonal_decompose(df['sensorsLogger.CO2'], model='additive', freq=1440)
b = decomposition.resid
#fig = decomposition.plot()
#matplotlib.rcParams['figure.figsize'] = [10.0, 6.0]

# %%
import matplotlib
import matplotlib.pyplot as plt
import statsmodels.api as sm

decomposition = sm.tsa.seasonal_decompose(df['sensorsLogger.CO2STD'], model='additive', freq=1440)
fig = decomposition.plot()
matplotlib.rcParams['figure.figsize'] = [10.0, 6.0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c202f636ede2> in <module>()
#       3 import statsmodels.api as sm
#       4
# ----> 5 decomposition = sm.tsa.seasonal_decompose(df['sensorsLogger.CO2STD'], model='additive', freq=1440)
#       6 fig = decomposition.plot()
#       7 matplotlib.rcParams['figure.figsize'] = [10.0, 6.0]
#
# NameError: name 'df' is not defined
